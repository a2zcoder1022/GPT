# %%
import torch.nn as nn
from Transformer import Transformer

vocab_size = 10000
d_model = 512
n_heads = 8
num_layers = 6
ff_hidden_dim = 2048
max_len = 100
transformer = Transformer(vocab_size, d_model, n_heads, num_layers, ff_hidden_dim, max_len)

# %%
from datasets import load_dataset

data = load_dataset("cord19", "metadata")
data = data["train"].to_pandas()

# %%
data = data[["abstract"]]

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

# %%
data["abstract"] = data["abstract"].str.lower()
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_39272\56087317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["abstract"] = data["abstract"].str.lower()

# %%
tokenizer = Tokenizer(BPE())


trainer = BpeTrainer(vocab_size=10000, min_frequency=1)
tokenizer.pre_tokenizer = Whitespace()

# %%
tokenizer.train_from_iterator(list(data["abstract"]), trainer)

# %%
tokenizer.get_vocab()
# Out:
# {'tobac': 9144,
#  'ous': 2990,
#  '54': 5428,
#  'ト': 644,
#  'drop': 9353,
#  'ning': 3504,
#  'visible': 9736,
#  'entry': 5068,
#  'why': 7973,
#  'ageal': 8382,
#  'cost': 4231,
#  'items': 7441,
#  'molecule': 7243,
#  '80': 4323,
#  '宴': 1178,
#  'infrastructure': 7660,
#  '習': 2086,
#  'favor': 6340,
#  'identity': 8167,
#  'diarrho': 8585,
#  'uce': 3734,
#  'ing': 2763,
#  'proper': 4358,
#  'utions': 4773,
#  'composite': 8088,
#  '拉': 1423,
#  'appe': 4300,
#  '殺': 1653,
#  '96': 4999,
#  'cc': 5768,
#  'ʰ': 221,
#  'pack': 7502,
#  'deployment': 9149,
#  'ṣ': 365,
#  'tri': 3041,
#  'iring': 5410,
#  'ectomy': 7428,
#  'crystal': 8089,
#  '洁': 1704,
#  'echo': 8233,
#  'das': 7833,
#  'introduce': 8449,
#  'plastic': 7385,
#  'cooperation': 9892,
#  'fir': 3104,
#  'dro': 3165,
#  'exer': 5264,
#  'ward': 5529,
#  'ampli': 6000,
#  'hospitalisation': 9951,
#  'contr': 4621,
#  '百': 1889,
#  'pres': 2898,
#  'strict': 6907,
#  'easily': 7614,
#  'rel': 3005,
#  '划': 899,
# ...

# %%
tokenizer.encode(data["text"].loc[0].split(".")[0]).tokens
# Out:
# ['myco',
#  'plasma',
#  'pneumoniae',
#  'is',
#  'a',
#  'common',
#  'cause',
#  'of',
#  'upper',
#  'and',
#  'lower',
#  'respiratory',
#  'tract',
#  'infections']
